# %% [markdown]
# # **Naive Bayes Classifier**

# %% [markdown]
# ```Iris``` dataset description [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) \
# ```GaussianNB``` documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris # Iris dataset

# %%
iris = load_iris() # Load the iris dataset
iris_X = iris.data[:, 0:2] # Features. We'll pick 2 extraer datos
iris_y = iris.target # Labels extraer labels

# Print shapes
print ( iris_X.shape )
print ( iris_y.shape )

#ax es el eje se usa el _ para que no guarde la figura en memoria
_, ax = plt.subplots(figsize=(6 , 5))
ax.scatter(iris_X[: , 0], iris_X[: , 1], c=iris_y, cmap='Paired', edgecolors='k')


# Es linealmente separable por la clase azul
# Las clases rojas y amarillas no son linealmente separables
# Out:
# (150, 2)
# (150,)

# %%
# Instance kNN object
naive_bayes = GaussianNB()

# Training
naive_bayes.fit( iris_X , iris_y )
# Out:
# GaussianNB()

# %%
## Plot decision boundaries
# Definir rango para el grid sobre el cual visualizar la frontera
offset = 0.1 # Solo visualizacion se pone una valor razonable
resolution = 100
x_min, x_max = iris_X[:, 0].min() - offset, iris_X[:, 0].max() + offset
y_min, y_max = iris_X[:, 1].min() - offset, iris_X[:, 1].max() + offset

# Crear grilla de puntos con resolución 100x100
x_grid, y_grid = np.meshgrid(
    np.linspace(x_min, x_max, resolution),
    np.linspace(y_min, y_max, resolution)
)

# Predecir clase para cada punto del grid
predictions = naive_bayes.predict(np.c_[x_grid.ravel(), y_grid.ravel()]) # convertir a unidimensional las muestras que queremos predecir, se concatenan los arreglos con np.c_
print("Shape of predictions:", predictions.shape)
predictions = predictions.reshape(x_grid.shape)
print("Shape of predictions:", predictions.shape)

# Graficar
_, ax = plt.subplots(figsize=(6 , 5))
#ax.pcolormesh(x_grid, y_grid, predictions, cmap='Paired')
ax.contourf(x_grid, y_grid, predictions, cmap='Paired')
ax.scatter(iris_X[: , 0], iris_X[: , 1], c=iris_y, cmap='Paired', edgecolors='k')
# Out:
# Shape of predictions: (10000,)
# Shape of predictions: (100, 100)

# %% [markdown]
# ## On real data - Fruits dataset
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
fruit_data = _ # Load the fruits dataset
fruits_x = _  # Features. We'll pick 2
fruits_y = _  # Labels

# Convert everything to a np array
fruits_x, fruits_y = np.asarray(fruits_x), np.asarray(fruits_y)

# Print shapes
print ( _ )

# %%
# Instance GaussianNB object
naive_bayes = GaussianNB()

# Training
 _ #(num_samples, Features)

# %%
## Plot decision boundaries
_
