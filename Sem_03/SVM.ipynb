# %% [markdown]
# # **Support Vector Boundary**

# %% [markdown]
# Isotropic data generator documentation [aquí](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) \
# Support vector classifier documentation [aquí](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs

# %%
# we create 40 separable points
X, y = make_blobs(n_samples = 100 , centers = 2 , random_state = 6)

_, ax = plt.subplots(figsize=(6,5))
ax.scatter( X[:,0] , X[:,1] , c = y , cmap="Paired") # le entrego un string y va a buscar la funcion o le entrego la funcion para que no vaya a buscar nada

# %%
clf = svm.SVC(kernel = 'linear' ) # clasificador
clf.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
x_min, x_max = X[:, 0].min(), X[:, 0].max()
y_min, y_max = X[:, 1].min(), X[:, 1].max()

# Crear el grid de las fronteras de decision
x_grid, y_grid = np.meshgrid(np.linspace( x_min , x_min , 100), np.linspace( y_max , y_max , 100))

# Predecir los valores del grid
#predictions = clf.decision_function(np.c_[x_grid.ravel(), y_grid.ravel()]) # decision funcion se le entrega
predictions = clf.predict(np.c_[x_grid.ravel(), y_grid.ravel()]) # decision funcion se le entrega
print (predictions.shape)

# Encajar las predicciones al tamaño del grid
predictions = predictions.reshape( x_grid.shape )
print (predictions.shape)
# Out:
# (10000,)
# (100, 100)

# %%
_, ax = plt.subplots (figsize=(8,5))

# plot decision boundary and margins
ax.pcolormesh( x_grid , y_grid , predictions , cmap='Paired') # curvas de nivel cuadriculas se le pasan - usualmente es al rededor de 0 los niveles por que hace referencia a la linea intermendia y las lineas de los extremos de las clases son punteadas
ax.scatter( X[:,0] , X[:,1] , c = y , s = 30, cmap = plt.cm.Paired) #parameter size

# alpha es un overlay

# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k') # facecolor none no grafico con colores y solo se pinta el borde

# %% [markdown]
# ## In real data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import load_iris

# %%
# import some data to play with
iris = _
X = _   # Pick 2 features
Y = _

# %%
# Create an instance of SVM and fit the data.
clf = _
clf.fit( _ , _ )

# %%
# Plot decision boundaries
_
