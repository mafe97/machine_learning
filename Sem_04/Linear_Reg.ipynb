# %% [markdown]
# # **Linear Regresion**

# %% [markdown]
# ```linear_regression``` module documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linear%20regression#sklearn.linear_model.LinearRegression)

# %%
import numpy as np # Numerical library
import matplotlib.pyplot as plt # plots
from sklearn.linear_model import LinearRegression

# %%
def f(x) : # Create a function that samples from linear function
  y = (0.0918 * x) + 1.2859 + 0.1*np.random.randn (x.shape[0]) # Linear function (desde 0.1... es ruido)
  return y

# create training samples
x = np.arange (0, 20, 0.25); print (x.shape)
# Generate samples
y = f(x) ; print (y.shape)
#sklearn espera siempre un arreglo de 2 dimensiones filas y cols hay que hacer un reshap para convertirlo a uno bidimensional
# Scatter plot
plt.scatter(x, y, color = 'blue')
# Out:
# (80,)
# (80,)

# %%
# Create an instance
linear_regression = LinearRegression()

# Train the model
linear_regression.fit( x.reshape(-1, 1) , y ) # (# Samples, # Features)

# Print estimated values
print ("w = " + str(linear_regression.coef_) + ", b = " + str(linear_regression.intercept_))
# Out:
# w = [0.09205099], b = 1.293421421600263

# %%
# Create a new sample estimate prediction
new_sample = np.array([5]); print (new_sample.shape)
# Predict the new sample
print (f(new_sample))

prediction = linear_regression.predict( new_sample.reshape(-1, 1) )
print (prediction)
# Out:
# (1,)
# [1.64620688]
# [1.75367636]

# %%
# Predict x values
predictions = linear_regression.predict( x.reshape(-1, 1) )

# Draw real samples (blue) and predictions (red)
_, ax = plt.subplots (figsize = ( 5 , 4 ))
ax.scatter( x , y , color = 'blue')
ax.plot ( x , predictions , color = 'red') #(pensiente:datos, independiente:predicciones)

# %% [markdown]
# ## In Synthetic data

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
X, y = make_regression(n_samples = 200 , n_features = 2, noise = 10, random_state = 5 )

_, ax = plt.subplots (figsize=( 5 , 4 ))
ax.scatter( X[:, 1] , y , c = 'b') #usar 0 y 1 para crear la relacion con y
print (X.shape, y.shape)
# Out:
# (200, 2) (200,)

# %%
linear_regression = LinearRegression()
linear_regression.fit( X , y )

# Imprimir los valores estimados para compararlos respecto a los originales
print ("w = " + str(linear_regression.coef_) + ", b = " + str(linear_regression.intercept_))
# Out:
# w = [-0.59041983 68.56680258], b = -0.3593188020508755

# %%
# Nueva muestra. Imprime el valor correspondiente de y
new_sample = np.array([1])

# Predecir la nueva muestra. Imprimir la prediccion
prediction = linear_regression.predict( 200 )
print (prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-879441858.py in <cell line: 0>()
#       3
#       4 # Predecir la nueva muestra. Imprimir la prediccion
# ----> 5 prediction = linear_regression.predict( 200 )
#       6 print (prediction)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
#     278         if coef_.ndim == 1:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1068             # If input is scalar raise error
#    1069             if array.ndim == 0:
# -> 1070                 raise ValueError(
#    1071                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#    1072                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=200.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
predictions = linear_regression.predict( X )

# %%
_, axes = plt.subplots (1, 2, figsize=( 10 , 4 ))
axes[0].scatter( X[:, 0] , y ,alpha=0.5, c='blue') #usar 0 y 1 para crear la relacion con y
axes[0].scatter(X[:, 0], predictions, alpha=0.5, c='red')
axes[1].scatter( X[:, 1] , y ,alpha=0.5, c='blue') #usar 0 y 1 para crear la relacion con y
axes[1].scatter(X[:, 1], predictions, alpha=0.5, c='red')
print (X.shape, y.shape)
# Out:
# (200, 2) (200,)

# %% [markdown]
# ## In real data

# %% [markdown]
# ```datasets``` module info [here](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets)

# %%
import numpy as np
import matplotlib.pyplot as plt # plots
from sklearn.linear_model import LinearRegression # scikit-learn: libreria de IA para python
from sklearn.datasets import load_diabetes

# %%
# Cargar la base de datos Diabetes
diabetes_X, diabetes_y = load_diabetes(return_X_y=True)
print(diabetes_X.shape, diabetes_y.shape)

# %%
# Use only one feature
diabetes_X = _
diabetes_X = diabetes_X[:, np.newaxis]
print(diabetes_X.shape, diabetes_y.shape)

# %%
# Linear regression
linear_regression = LinearRegression()

# Train the model
linear_regression.fit( diabetes_X , diabetes_y )

# %%
# Make predictions using the testing set
diabetes_y_pred = linear_regression.predict( _ )


print ("w = " + str( linear_regression.coef_ ) + ", b = " + str( linear_regression.intercept_ ))
# Out:
# w = [949.43526038], b = 152.13348416289617

# %%
# Plot outputs
_, ax = plt.subplots (figsize=( _ , _ ))
ax.scatter( _ , _  , color = "blue")
ax.plot( _ , _ , color = "red")
